# %%
import pandas as pd
df = pd.read_csv('nba.csv', index_col=0)
df
# Out:
#                                            Team  Number Position   Age Height  \
# Name
# Avery Bradley                    Boston Celtics     0.0       PG  25.0    6-2
# Jae Crowder                      Boston Celtics    99.0       SF  25.0    6-6
# John Holland                     Boston Celtics    30.0       SG  27.0    6-5
# R.J. Hunter                      Boston Celtics    28.0       SG  22.0    6-5
# Jonas Jerebko                    Boston Celtics     8.0       PF  29.0   6-10
# Amir Johnson                     Boston Celtics    90.0       PF  29.0    6-9
# Jordan Mickey                    Boston Celtics    55.0       PF  21.0    6-8
# Kelly Olynyk                     Boston Celtics    41.0        C  25.0    7-0
# Terry Rozier                     Boston Celtics    12.0       PG  22.0    6-2
# Marcus Smart                     Boston Celtics    36.0       PG  22.0    6-4
# Jared Sullinger                  Boston Celtics     7.0        C  24.0    6-9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 458 entries, Avery Bradley to nan
# Data columns (total 8 columns):
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(4)
# memory usage: 32.2+ KB

# %%
df.isna().any()
# Out:
# Team        True
# Number      True
# Position    True
# Age         True
# Height      True
# Weight      True
# College     True
# Salary      True
# dtype: bool

# %%
df.isna().sum()
# Out:
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
df["College"].fillna("No College", inplace = True) 
df
# Out:
#                                            Team  Number Position   Age Height  \
# Name
# Avery Bradley                    Boston Celtics     0.0       PG  25.0    6-2
# Jae Crowder                      Boston Celtics    99.0       SF  25.0    6-6
# John Holland                     Boston Celtics    30.0       SG  27.0    6-5
# R.J. Hunter                      Boston Celtics    28.0       SG  22.0    6-5
# Jonas Jerebko                    Boston Celtics     8.0       PF  29.0   6-10
# Amir Johnson                     Boston Celtics    90.0       PF  29.0    6-9
# Jordan Mickey                    Boston Celtics    55.0       PF  21.0    6-8
# Kelly Olynyk                     Boston Celtics    41.0        C  25.0    7-0
# Terry Rozier                     Boston Celtics    12.0       PG  22.0    6-2
# Marcus Smart                     Boston Celtics    36.0       PG  22.0    6-4
# Jared Sullinger                  Boston Celtics     7.0        C  24.0    6-9
# ...

# %%
df.isna().sum()
# Out:
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College      0
# Salary      12
# dtype: int64

# %%
columns = {'Salary': df.Salary.mean()}
df = df.fillna(columns)

# %%
df.isna().sum()
# Out:
# Team        1
# Number      1
# Position    1
# Age         1
# Height      1
# Weight      1
# College     0
# Salary      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 458 entries, Avery Bradley to nan
# Data columns (total 8 columns):
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     458 non-null object
# Salary      458 non-null float64
# dtypes: float64(4), object(4)
# memory usage: 32.2+ KB

# %%
df = df.dropna(axis = 0, how = 'any')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 457 entries, Avery Bradley to Jeff Withey
# Data columns (total 8 columns):
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     457 non-null object
# Salary      457 non-null float64
# dtypes: float64(4), object(4)
# memory usage: 32.1+ KB

# %%
df.isna().any()
# Out:
# Team        False
# Number      False
# Position    False
# Age         False
# Height      False
# Weight      False
# College     False
# Salary      False
# dtype: bool

# %%
df.sample(frac=0.2)
# Out:
#                                             Team  Number Position   Age  \
# Name
# Maurice Harkless          Portland Trail Blazers     4.0       SF  23.0
# Lance Thomas                     New York Knicks    42.0       SF  28.0
# Delon Wright                     Toronto Raptors    55.0       PG  24.0
# Andrew Goudelock                 Houston Rockets     0.0       PG  27.0
# Bojan Bogdanovic                   Brooklyn Nets    44.0       SG  27.0
# Kevin Seraphin                   New York Knicks     1.0        C  26.0
# Boris Diaw                     San Antonio Spurs    33.0        C  34.0
# Lance Stephenson               Memphis Grizzlies     1.0       SF  25.0
# Joel Embiid                   Philadelphia 76ers    21.0        C  22.0
# Elfrid Payton                      Orlando Magic     4.0       PG  22.0
# Tony Parker                    San Antonio Spurs     9.0       PG  34.0
# Marcus Thornton               Washington Wizards    15.0       SF  29.0
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pd.pivot_table(df,index=["Team"],values=["Salary"],aggfunc=[np.mean])
# Out:
#                                 mean
#                               Salary
# Team
# Atlanta Hawks           4.860197e+06
# Boston Celtics          4.225583e+06
# Brooklyn Nets           3.501898e+06
# Charlotte Hornets       5.222728e+06
# Chicago Bulls           5.785559e+06
# Cleveland Cavaliers     7.455425e+06
# Dallas Mavericks        4.746582e+06
# Denver Nuggets          4.330974e+06
# Detroit Pistons         4.477884e+06
# Golden State Warriors   5.924600e+06
# Houston Rockets         5.018868e+06
# Indiana Pacers          4.450122e+06
# Los Angeles Clippers    6.323643e+06
# Los Angeles Lakers      4.784695e+06
# Memphis Grizzlies       5.328979e+06
# Miami Heat              6.146736e+06
# Milwaukee Bucks         4.350220e+06
# Minnesota Timberwolves  4.610884e+06
# New Orleans Pelicans    4.355304e+06
# New York Knicks         4.581494e+06
# Oklahoma City Thunder   6.251020e+06
# Orlando Magic           4.297248e+06
# Philadelphia 76ers      2.389039e+06
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df2 = df.loc[df['Team'] == 'Boston Celtics']
df2
# Out:
#                            Team  Number Position   Age Height  Weight  \
# Name
# Avery Bradley    Boston Celtics     0.0       PG  25.0    6-2   180.0
# Jae Crowder      Boston Celtics    99.0       SF  25.0    6-6   235.0
# John Holland     Boston Celtics    30.0       SG  27.0    6-5   205.0
# R.J. Hunter      Boston Celtics    28.0       SG  22.0    6-5   185.0
# Jonas Jerebko    Boston Celtics     8.0       PF  29.0   6-10   231.0
# Amir Johnson     Boston Celtics    90.0       PF  29.0    6-9   240.0
# Jordan Mickey    Boston Celtics    55.0       PF  21.0    6-8   235.0
# Kelly Olynyk     Boston Celtics    41.0        C  25.0    7-0   238.0
# Terry Rozier     Boston Celtics    12.0       PG  22.0    6-2   190.0
# Marcus Smart     Boston Celtics    36.0       PG  22.0    6-4   220.0
# Jared Sullinger  Boston Celtics     7.0        C  24.0    6-9   260.0
# Isaiah Thomas    Boston Celtics     4.0       PG  27.0    5-9   185.0
# ...

# %%
pd.pivot_table(df2,index=["Team","Name"],values=["Salary"])
# Out:
#                                     Salary
# Team           Name
# Boston Celtics Amir Johnson     12000000.0
#                Avery Bradley     7730337.0
#                Evan Turner       3425510.0
#                Isaiah Thomas     6912869.0
#                Jae Crowder       6796117.0
#                James Young       1749840.0
#                Jared Sullinger   2569260.0
#                Jonas Jerebko     5000000.0
#                Jordan Mickey     1170960.0
#                Kelly Olynyk      2165160.0
#                Marcus Smart      3431040.0
#                R.J. Hunter       1148640.0
#                Terry Rozier      1824360.0
#                Tyler Zeller      2616975.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pd.pivot_table(df2,index=["Team"],values=["Salary"],aggfunc=[np.mean])
# Out:
#                         mean
#                       Salary
# Team
# Boston Celtics  4.225583e+06

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pd.pivot_table(df2,index=["Age","Height"],values=["Weight"],aggfunc=[np.mean])
# Out:
#               mean
#             Weight
# Age  Height
# 20.0 6-6     215.0
# 21.0 6-8     235.0
# 22.0 6-2     190.0
#      6-4     220.0
#      6-5     185.0
# 24.0 6-9     260.0
# 25.0 6-2     180.0
#      6-6     235.0
#      7-0     238.0
# 26.0 7-0     253.0
# 27.0 5-9     185.0
#      6-5     205.0
#      6-7     220.0
# 29.0 6-10    231.0
#      6-9     240.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df4 = pd.pivot_table(df,index=["College"],values=["Salary"],aggfunc=[np.mean])
df4
# Out:
#                                mean
#                              Salary
# College
# Alabama                1.421686e+06
# Arizona                3.325948e+06
# Arizona State          7.933941e+06
# Arkansas               2.713180e+06
# Baylor                 9.813480e+05
# Belmont                9.472760e+05
# Blinn College          5.000000e+06
# Boston College         9.144022e+06
# Boston University      4.842684e+06
# Bowling Green          1.074169e+06
# Bucknell               9.472760e+05
# Butler                 8.921452e+06
# California             3.212244e+06
# Central Michigan       5.016000e+06
# Charleston             2.006000e+05
# Cincinnati             4.567108e+06
# Clemson                3.982397e+06
# Cleveland State        3.036927e+06
# Colorado               3.839781e+06
# Colorado State         4.300000e+06
# Connecticut            4.914350e+06
# Creighton              3.708973e+06
# Davidson               1.137079e+07
# Dayton                 1.918144e+06
# ...

# %%
df5 = df4.sort_index(level='College', sort_remaining=True) \
      .sort_values('Salary', ascending=False)
df5
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-c13f928f492b> in <module>
#       1 df5 = df4.sort_index(level='College', sort_remaining=True) \
# ----> 2       .sort_values('Salary', ascending=False)
#       3 df5
#
# /usr/local/lib64/python3.6/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4717
#    4718             by = by[0]
# -> 4719             k = self._get_label_or_level_values(by, axis=axis)
#    4720
#    4721             if isinstance(ascending, (tuple, list)):
#
# /usr/local/lib64/python3.6/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1705             values = self.axes[axis].get_level_values(key)._values
#    1706         else:
# -> 1707             raise KeyError(key)
#    1708
#    1709         # Check for duplicates
#
# KeyError: 'Salary'

# %%
df4.sort_values('Salary', ascending=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-64-6101f1c0d7e3> in <module>
# ----> 1 df4.sort_values('Salary', ascending=False)
#
# /usr/local/lib64/python3.6/site-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    4717
#    4718             by = by[0]
# -> 4719             k = self._get_label_or_level_values(by, axis=axis)
#    4720
#    4721             if isinstance(ascending, (tuple, list)):
#
# /usr/local/lib64/python3.6/site-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1705             values = self.axes[axis].get_level_values(key)._values
#    1706         else:
# -> 1707             raise KeyError(key)
#    1708
#    1709         # Check for duplicates
#
# KeyError: 'Salary'

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pd.pivot_table(df,index=["Team"],values=["Age"],aggfunc=[np.mean])
# Out:
#                              mean
#                               Age
# Team
# Atlanta Hawks           28.200000
# Boston Celtics          24.733333
# Brooklyn Nets           25.600000
# Charlotte Hornets       26.133333
# Chicago Bulls           27.400000
# Cleveland Cavaliers     29.533333
# Dallas Mavericks        29.733333
# Denver Nuggets          25.733333
# Detroit Pistons         26.200000
# Golden State Warriors   27.666667
# Houston Rockets         26.866667
# Indiana Pacers          26.400000
# Los Angeles Clippers    29.466667
# Los Angeles Lakers      27.533333
# Memphis Grizzlies       28.388889
# Miami Heat              28.933333
# Milwaukee Bucks         24.562500
# Minnesota Timberwolves  26.357143
# New Orleans Pelicans    26.894737
# New York Knicks         27.000000
# Oklahoma City Thunder   27.066667
# Orlando Magic           25.071429
# Philadelphia 76ers      24.600000
# Phoenix Suns            25.866667
# Portland Trail Blazers  25.066667
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pd.pivot_table(df,index=["College"],values=["Age"],aggfunc=[np.mean])
# Out:
#                             mean
#                              Age
# College
# Alabama                29.000000
# Arizona                27.384615
# Arizona State          27.500000
# Arkansas               27.333333
# Baylor                 25.000000
# Belmont                25.000000
# Blinn College          37.000000
# Boston College         28.000000
# Boston University      27.000000
# Bowling Green          22.000000
# Bucknell               24.000000
# Butler                 26.000000
# California             26.333333
# Central Michigan       34.000000
# Charleston             27.000000
# Cincinnati             25.500000
# Clemson                25.500000
# Cleveland State        27.000000
# Colorado               23.666667
# Colorado State         30.000000
# Connecticut            27.428571
# Creighton              30.000000
# Davidson               28.000000
# Dayton                 28.000000
# DePaul                 29.000000
# Detroit                24.000000
# ...

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
pd.pivot_table(df,index=["Team"],values=["Age"],aggfunc=[np.count_nonzero])
# Out:
#                        count_nonzero
#                                  Age
# Team
# Atlanta Hawks                   15.0
# Boston Celtics                  15.0
# Brooklyn Nets                   15.0
# Charlotte Hornets               15.0
# Chicago Bulls                   15.0
# Cleveland Cavaliers             15.0
# Dallas Mavericks                15.0
# Denver Nuggets                  15.0
# Detroit Pistons                 15.0
# Golden State Warriors           15.0
# Houston Rockets                 15.0
# Indiana Pacers                  15.0
# Los Angeles Clippers            15.0
# Los Angeles Lakers              15.0
# Memphis Grizzlies               18.0
# Miami Heat                      15.0
# Milwaukee Bucks                 16.0
# Minnesota Timberwolves          14.0
# New Orleans Pelicans            19.0
# New York Knicks                 16.0
# Oklahoma City Thunder           15.0
# Orlando Magic                   14.0
# Philadelphia 76ers              15.0
# ...
