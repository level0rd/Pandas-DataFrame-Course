# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # Функция Apply
# # Пример 1

# %%
import pandas as pd
dict = {"name" : ["Daniel", "John", "Jane"],
        "treatment_a" : [18, 12, 24],
        "treatment_b" : [42, 31, 27]}

# %%
df = pd.DataFrame(dict)

# %%
df
# Out:
#      name  treatment_a  treatment_b
# 0  Daniel           18           42
# 1    John           12           31
# 2    Jane           24           27

# %%
df2 = pd.DataFrame(df, columns=["treatment_a", "treatment_b"])

# %%
import numpy as np
df2.apply(np.mean, axis=0)
# Out:
# treatment_a    18.000000
# treatment_b    33.333333
# dtype: float64

# %% [markdown]
# # Пример 2

# %%
dict = {"Job" : [121577873, 52129502,  121601560, 121601203, 121601338],
        "Doc" : [2, 1, 1, 1, 1],
        "Borough" : ["MANHATTAN", "STATEN ISLAND", "MANHATTAN","MANHATTAN","MANHATTAN"],
        "Initial_Cost": ["$75000.00", "$0.00", "$30000.00", "$1500.00", "$19500.00"],
        "Total Est. Fee" : [ "$986.00", "$1144.00", "$522.50", "$225.00", "$389.50"]}

# %%
df = pd.DataFrame(dict)
df2=pd.DataFrame(dict)
df3=pd.DataFrame(dict)
df
# Out:
#          Job  Doc        Borough Initial_Cost Total Est. Fee
# 0  121577873    2      MANHATTAN    $75000.00        $986.00
# 1   52129502    1  STATEN ISLAND        $0.00       $1144.00
# 2  121601560    1      MANHATTAN    $30000.00        $522.50
# 3  121601203    1      MANHATTAN     $1500.00        $225.00
# 4  121601338    1      MANHATTAN    $19500.00        $389.50

# %% [markdown]
# ## 1

# %%
import re
from numpy import NaN

pattern = re.compile('^\$\d*\.\d{,2}$')


def diff_money(row, pattern):
    icost = row['Initial_Cost']
    tef = row ['Total Est. Fee']
    if bool(pattern.match(icost)) and bool(pattern.match(tef)):
        icost = icost.replace("$", "")
        tef = tef.replace("$", "")

        icost = float(icost)
        tef = float(tef)

        return icost - tef
    else:
        return(NaN)

# %%
df['diff'] = df.apply(diff_money, axis = 1, pattern = pattern)
df
# Out:
#          Job  Doc        Borough Initial_Cost Total Est. Fee     diff
# 0  121577873    2      MANHATTAN    $75000.00        $986.00  74014.0
# 1   52129502    1  STATEN ISLAND        $0.00       $1144.00  -1144.0
# 2  121601560    1      MANHATTAN    $30000.00        $522.50  29477.5
# 3  121601203    1      MANHATTAN     $1500.00        $225.00   1275.0
# 4  121601338    1      MANHATTAN    $19500.00        $389.50  19110.5

# %% [markdown]
# ## 2

# %%
df2
# Out:
#          Job  Doc        Borough Initial_Cost Total Est. Fee
# 0  121577873    2      MANHATTAN    $75000.00        $986.00
# 1   52129502    1  STATEN ISLAND        $0.00       $1144.00
# 2  121601560    1      MANHATTAN    $30000.00        $522.50
# 3  121601203    1      MANHATTAN     $1500.00        $225.00
# 4  121601338    1      MANHATTAN    $19500.00        $389.50

# %%
df2['Initial_Cost_Replace'] = df2.Initial_Cost.apply(lambda x: x.replace('$', ''))
df2
# Out:
#          Job  Doc        Borough Initial_Cost Total Est. Fee  \
# 0  121577873    2      MANHATTAN    $75000.00        $986.00
# 1   52129502    1  STATEN ISLAND        $0.00       $1144.00
# 2  121601560    1      MANHATTAN    $30000.00        $522.50
# 3  121601203    1      MANHATTAN     $1500.00        $225.00
# 4  121601338    1      MANHATTAN    $19500.00        $389.50
#
#   Initial_Cost_Replace
# 0             75000.00
# 1                 0.00
# 2             30000.00
# 3              1500.00
# 4             19500.00

# %% [markdown]
# ## 3

# %%
df3
# Out:
#          Job  Doc        Borough Initial_Cost Total Est. Fee
# 0  121577873    2      MANHATTAN    $75000.00        $986.00
# 1   52129502    1  STATEN ISLAND        $0.00       $1144.00
# 2  121601560    1      MANHATTAN    $30000.00        $522.50
# 3  121601203    1      MANHATTAN     $1500.00        $225.00
# 4  121601338    1      MANHATTAN    $19500.00        $389.50

# %%
df3['Initial_Cost_Replace'] = df3.Initial_Cost.apply(lambda x: re.findall('\d+\.\d+', x)[0])
df3
# Out:
#          Job  Doc        Borough Initial_Cost Total Est. Fee  \
# 0  121577873    2      MANHATTAN    $75000.00        $986.00
# 1   52129502    1  STATEN ISLAND        $0.00       $1144.00
# 2  121601560    1      MANHATTAN    $30000.00        $522.50
# 3  121601203    1      MANHATTAN     $1500.00        $225.00
# 4  121601338    1      MANHATTAN    $19500.00        $389.50
#
#   Initial_Cost_Replace
# 0             75000.00
# 1                 0.00
# 2             30000.00
# 3              1500.00
# 4             19500.00

# %% [markdown]
# # Заполнение пустых значений

# %%
dict = {"total_biil" : [16.99, np.nan, 21.01, 23.68, 24.59],
        "tip" : [1.01, 1.66, 3.50, np.nan, 3.61],
        "sex" : ["Female", "Male", "Male", "Male", np.nan],
        "smoker" : ["No", "No","No","No", np.nan],
        "day": ["Sun","Sun","Sun","Sun","Sun"],
        "time": ["Dinner","Dinner","Dinner","Dinner", np.nan],
        "size": [2.0,3.0,np.nan,2.0,4.0]}

# %%
#df = pd.DataFrame([[np.nan, 2, np.nan, 0],

#                   [3, 4, np.nan, 1],

#                   [np.nan, np.nan, np.nan, 5],

#                  [np.nan, 3, np.nan, 4]]

# %%
df = pd.DataFrame(dict)
df
# Out:
#    total_biil   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner   2.0
# 1         NaN  1.66    Male     No  Sun  Dinner   3.0
# 2       21.01  3.50    Male     No  Sun  Dinner   NaN
# 3       23.68   NaN    Male     No  Sun  Dinner   2.0
# 4       24.59  3.61     NaN    NaN  Sun     NaN   4.0

# %% [markdown]
# ## Что можно сделать с отсутствующими данными:
# ##     *Оставить как есть
# ##     *Удалить
# ##     *Заполнить недостающими значениями

# %% [markdown]
# # Заполнение корректными значениями:

# %% [markdown]
# ## По отдельности

# %%
df['sex'] = df['sex'].fillna('missing')
df
# Out:
#    total_biil   tip      sex smoker  day    time  size
# 0       16.99  1.01   Female     No  Sun  Dinner   2.0
# 1         NaN  1.66     Male     No  Sun  Dinner   3.0
# 2       21.01  3.50     Male     No  Sun  Dinner   NaN
# 3       23.68   NaN     Male     No  Sun  Dinner   2.0
# 4       24.59  3.61  missing    NaN  Sun     NaN   4.0

# %%
df[["total_biil"]].fillna(0, inplace = True) 
df["size"].fillna(0, inplace = True) 
df
# Out:
# /usr/local/lib64/python3.6/site-packages/pandas/core/frame.py:4034: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   downcast=downcast, **kwargs)
#    total_biil   tip      sex smoker  day    time  size
# 0       16.99  1.01   Female     No  Sun  Dinner   2.0
# 1         NaN  1.66     Male     No  Sun  Dinner   3.0
# 2       21.01  3.50     Male     No  Sun  Dinner   0.0
# 3       23.68   NaN     Male     No  Sun  Dinner   2.0
# 4       24.59  3.61  missing    NaN  Sun     NaN   4.0

# %% [markdown]
# ## Списком

# %%
columns = {'total_biil': 0,'size': 0}
df = df.fillna(columns)
df
# Out:
#    total_biil    tip      sex smoker  day    time  size
# 0       16.99  1.010   Female     No  Sun  Dinner   2.0
# 1        0.00  1.660     Male     No  Sun  Dinner   3.0
# 2       21.01  3.500     Male     No  Sun  Dinner   0.0
# 3       23.68  2.445     Male     No  Sun  Dinner   2.0
# 4       24.59  3.610  missing    NaN  Sun     NaN   4.0

# %%
df[['total_bill','size']] = df[['total_bill','size']].fillna(0)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-71715f1c1803> in <module>
# ----> 1 df[['total_bill','size']] = df[['total_bill','size']].fillna(0)
#       2 df
#
# /usr/local/lib64/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2932                 key = list(key)
#    2933             indexer = self.loc._convert_to_indexer(key, axis=1,
# -> 2934                                                    raise_missing=True)
#    2935
#    2936         # take() does not accept boolean indexers
#
# /usr/local/lib64/python3.6/site-packages/pandas/core/indexing.py in _convert_to_indexer(self, obj, axis, is_setter, raise_missing)
#    1352                 kwargs = {'raise_missing': True if is_setter else
#    1353                           raise_missing}
# -> 1354                 return self._get_listlike_indexer(obj, axis, **kwargs)[1]
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
# total_biil    4 non-null float64
# tip           4 non-null float64
# sex           5 non-null object
# smoker        4 non-null object
# day           5 non-null object
# time          4 non-null object
# size          5 non-null float64
# dtypes: float64(3), object(4)
# memory usage: 360.0+ bytes

# %% [markdown]
# ## Заполнение средними значениями

# %%
mean_value = df['tip'].mean()
mean_value
# Out:
# 2.445

# %%
df['tip'] = df['tip'].fillna(mean_value)
df
# Out:
#    total_biil    tip      sex smoker  day    time  size
# 0       16.99  1.010   Female     No  Sun  Dinner   2.0
# 1        0.00  1.660     Male     No  Sun  Dinner   3.0
# 2       21.01  3.500     Male     No  Sun  Dinner   0.0
# 3       23.68  2.445     Male     No  Sun  Dinner   2.0
# 4       24.59  3.610  missing    NaN  Sun     NaN   4.0
